# %%
import numpy as np
import pandas as pd

# %%
json = pd.read_json(r"C:\Users\Nikhil\OneDrive\Desktop\MY PERSONAL WORK\DATA SCIENCE\Projects\ReWear\ReWear\data\fashion-dataset\styles\1163.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-586/4231711005.py in <cell line: 0>()
# ----> 1 json = pd.read_json(r"C:\Users\Nikhil\OneDrive\Desktop\MY PERSONAL WORK\DATA SCIENCE\Projects\ReWear\ReWear\data\fashion-dataset\styles\1163.json")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ...
